# %%
# ============================================
# Retail Data Model
# ============================================

# This notebook defines retail entities and
# how data will be structured in Databricks.

# %%
# ============================================
# 1. Core Retail Entities
# ============================================

# Customers
# Products
# Orders
# Order Items
# Stores

# %%
# ============================================
# 2. Fact and Dimension Tables
# ============================================

# Dimension Tables:
# - dim_customers
# - dim_products
# - dim_stores
#
# Fact Tables:
# - fact_orders
# - fact_order_items

# %%
# ============================================
# 3. Fact vs Dimension Explanation
# ============================================

# Fact tables:
# - Contain transactional data
# - Used for aggregations
#
# Dimension tables:
# - Contain descriptive attributes
# - Used for filtering and grouping

# %%
# ============================================
# 4. Star Schema (Conceptual)
# ============================================

# fact_orders connects to:
# - dim_customers
# - dim_products
# - dim_stores
